# %%
import pandas as pd

df = pd.read_csv('../data/Clean Data_pakwheels.csv', encoding='latin1')

print(df.head(20))
print(df.info())
print(df.describe())
# Out:
#     Unnamed: 0 Company Name Model Name    Price  Model Year   Location  \
# 0            0       Toyota       Vitz  2385000        2017  Islamabad
# 1            1       Toyota    Corolla   111000        2019        KPK
# 2            2       Suzuki       Alto  1530000        2019        KPK
# 3            3       Suzuki       Alto  1650000        2019     Punjab
# 4            4       Toyota    Corolla  1435000        2010  Islamabad
# 5            5        Honda      Civic  3850000        2017     Punjab
# 6            6       Suzuki      Wagon  1440000        2017     Punjab
# 7            7   Mitsubishi     Mirage  1425000        2012     Punjab
# 8            8       Toyota      Prado  2650000        1998     Punjab
# 9            9        Honda      Civic  3350000        2017     Punjab
# 10          10        Honda      Vezel  3200000        2014      Sindh
# 11          11        Honda       City  1990000        2017     Punjab
# 12          12        Honda          N   185000        2016     Punjab
# 13          13       Suzuki     Cultus   920000        2012     Punjab
# 14          14       Toyota    Corolla  2750000        2018     Punjab
# 15          15        Honda          N  1150000        2017     Punjab
# 16          16        Honda       City   910000        2004     Punjab
# 17          17       Toyota   Fortuner  8650000        2018     Punjab
# 18          18       Suzuki      Wagon  1625000        2016     Punjab
# 19          19        Honda       City  2100000        2016     Punjab
#
#     Mileage Engine Type  Engine Capacity   Color  Assembly   Body Type  \
# 0      9869      Petrol             1000  Silver  Imported   Hatchback
# 1     11111      Petrol             1300   White     Local       Sedan
# 2     17500      Petrol              660   White     Local   Hatchback
# 3      9600      Petrol              660   White     Local   Hatchback
# 4    120000      Petrol             1300   Black     Local       Sedan
# 5     22000      Petrol             1500   Black     Local       Sedan
# 6     31000      Petrol             1000   White     Local   Hatchback
# 7    101000      Petrol             1000   Black  Imported   Hatchback
# 8    110000      Diesel             3000   Beige  Imported         SUV
# 9     60000      Petrol             1800   White     Local       Sedan
# 10    91000      Hybrid             1500   Black  Imported  Cross Over
# 11    75000      Petrol             1300   White     Local       Sedan
# 12    20000      Petrol              660   Black  Imported   Hatchback
# 13    83000      Petrol             1000    Grey     Local   Hatchback
# 14    51240      Petrol             1300   White     Local       Sedan
# 15   100000      Petrol              660   Black  Imported   Hatchback
# 16   150000      Petrol             1300    Grey     Local       Sedan
# 17    35000      Diesel             2800   White     Local         SUV
# 18    45000      Petrol              660   Brown  Imported   Hatchback
# 19    58000      Petrol             1300   White     Local       Sedan
#
#    Transmission Type Registration Status
# 0          Automatic       Un-Registered
# 1          Automatic          Registered
# 2          Automatic       Un-Registered
# 3             Manual          Registered
# 4             Manual          Registered
# 5          Automatic          Registered
# 6             Manual          Registered
# 7          Automatic          Registered
# 8          Automatic          Registered
# 9          Automatic          Registered
# 10         Automatic          Registered
# 11            Manual          Registered
# 12         Automatic          Registered
# 13            Manual          Registered
# 14         Automatic          Registered
# 15         Automatic          Registered
# 16            Manual          Registered
# 17         Automatic          Registered
# 18         Automatic       Un-Registered
# 19            Manual          Registered
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46022 entries, 0 to 46021
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           46022 non-null  int64
#  1   Company Name         46022 non-null  object
#  2   Model Name           46022 non-null  object
#  3   Price                46022 non-null  int64
#  4   Model Year           46022 non-null  int64
#  5   Location             46022 non-null  object
#  6   Mileage              46022 non-null  int64
#  7   Engine Type          46022 non-null  object
#  8   Engine Capacity      46022 non-null  int64
#  9   Color                46022 non-null  object
#  10  Assembly             46022 non-null  object
#  11  Body Type            46022 non-null  object
#  12  Transmission Type    46022 non-null  object
#  13  Registration Status  46022 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 4.9+ MB
# None
#          Unnamed: 0         Price    Model Year        Mileage  \
# count  46022.000000  4.602200e+04  46022.000000   46022.000000
# mean   23010.526205  2.014153e+06   2011.035374   90965.128243
# std    13285.595581  2.939071e+06      6.399403   63656.656034
# min        0.000000  1.110000e+05   1990.000000       1.000000
# 25%    11505.250000  8.500000e+05   2007.000000   48899.500000
# 50%    23010.500000  1.450000e+06   2013.000000   80000.000000
# 75%    34515.750000  2.300000e+06   2016.000000  120000.000000
# max    46022.000000  7.750000e+07   2019.000000  999999.000000
#
#        Engine Capacity
# count     46022.000000
# mean       1313.115575
# std         614.690832
# min          16.000000
# 25%        1000.000000
# 50%        1300.000000
# 75%        1500.000000
# max        6600.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Company Name           0
# Model Name             0
# Price                  0
# Model Year             0
# Location               0
# Mileage                0
# Engine Type            0
# Engine Capacity        0
# Color                  0
# Assembly               0
# Body Type              0
# Transmission Type      0
# Registration Status    0
# dtype: int64

# %%
import seaborn as sns

sns.boxplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %%
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1

df = df[(df['Price'] >= Q1 - 1.5*IQR) & (df['Price'] <= Q3 + 1.5*IQR)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Q1 = df['Price'].quantile(0.25)
#       2 Q3 = df['Price'].quantile(0.75)
#       3 IQR = Q3 - Q1
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>
